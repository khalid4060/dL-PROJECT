# %%
import keras
import numpy as np
import pandas as pd
from keras.layers import Dense,Dropout,LSTM,BatchNormalization
from keras.models import Sequential
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-138c7f82-8d32-424a-8c38-4bc47dd5c276" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-138c7f82-8d32-424a-8c38-4bc47dd5c276">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
df=pd.read_csv('/content/datasets_20469_26460_Google_Stock_Price_Train.csv')

# %%
#df['Close']=df['Close'].astype('float')
df['Close']=df['Close'].apply(lambda x: x.replace(',', '')).astype('float')

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_axis(df['Date'], inplace=True)
df.drop(columns=['Open', 'High', 'Low', 'Volume'], inplace=True)

# %%
close_data = df['Close'].values
close_data = close_data.reshape((-1,1))

split_percent = 0.80
split = int(split_percent*len(close_data))

close_train = close_data[:split]
close_test = close_data[split:]

date_train = df['Date'][:split]
date_test = df['Date'][split:]

# %%
from keras.preprocessing.sequence import TimeseriesGenerator

# %%
train_generator = TimeseriesGenerator(close_data,close_data, length=15, batch_size=20)  
test_generator = TimeseriesGenerator(close_test, close_test, length=15, batch_size=1)

# %%
test_generator1

# %%
model = Sequential()
model.add(LSTM(10,activation='relu',input_shape=(15,1)))
#model.add(Dropout(0.2))


model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.fit_generator(train_generator, epochs=21)
# Out:
# Epoch 1/21
# 63/63 [==============================] - 0s 6ms/step - loss: 1674.7745
# Epoch 2/21
# 63/63 [==============================] - 0s 6ms/step - loss: 3651.6027
# Epoch 3/21
# 63/63 [==============================] - 0s 5ms/step - loss: 14112.8899
# Epoch 4/21
# 63/63 [==============================] - 0s 6ms/step - loss: 8202.6664
# Epoch 5/21
# 63/63 [==============================] - 0s 6ms/step - loss: 3208.0901
# Epoch 6/21
# 63/63 [==============================] - 0s 6ms/step - loss: 11405.6225
# Epoch 7/21
# 63/63 [==============================] - 0s 5ms/step - loss: 3334.3276
# Epoch 8/21
# 63/63 [==============================] - 0s 6ms/step - loss: 1450.1770
# Epoch 9/21
# 63/63 [==============================] - 0s 6ms/step - loss: 5331.3696
# Epoch 10/21
# 63/63 [==============================] - 0s 6ms/step - loss: 1859.5931
# Epoch 11/21
# 63/63 [==============================] - 0s 6ms/step - loss: 1831.8092
# Epoch 12/21
# ...

# %%
import plotly.graph_objects as go
prediction = model.predict_generator(test_generator)

close_train = close_train.reshape((-1))
close_test = close_test.reshape((-1))
prediction = prediction.reshape((-1))

trace1 = go.Scatter(
    x = date_train,
    y = close_train,
    mode = 'lines',
    name = 'Data'
)
trace2 = go.Scatter(
    x = date_test,
    y = prediction,
    mode = 'lines',
    name = 'Prediction'
)
trace3 = go.Scatter(
    x = date_test,
    y = close_test,
    mode='lines',
    name = 'Ground Truth'
)
layout = go.Layout(
    title = "Google Stock",
    xaxis = {'title' : "Date"},
    yaxis = {'title' : "Close"}
)
fig = go.Figure(data=[trace1, trace2, trace3], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="579ffdc4-5796-4489-a8dc-f1209231d436" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("579ffdc4-5796-4489-a8dc-f1209231d436")) {
#                     Plotly.newPlot(
#                         '579ffdc4-5796-4489-a8dc-f1209231d436',
# ...

# %%
test_df=pd.read_csv('/content/datasets_20469_26460_Google_Stock_Price_Test.csv')

# %%
test_df['Date'] = pd.to_datetime(test_df['Date'])
test_df.set_axis(test_df['Date'], inplace=True)
test_df.drop(columns=['Open', 'High', 'Low', 'Volume'], inplace=True)

# %%
close_testdata =test_df['Close'].values

# %%
close_testdata=close_testdata.reshape((-1,1))

# %%
close_testdata.shape
# Out:
# (20, 1)

# %%
test_generator2 = TimeseriesGenerator(close_testdata,close_testdata, length=15, batch_size=20)

# %%
prediction = model.predict_generator(test_generator2)

# %%
date_train = df['Date']
date_test = test_df['Date']

# %%
close_data = close_data.reshape((-1))
close_testdata = close_testdata.reshape((-1))
prediction = prediction.reshape((-1))

# %%
import plotly.graph_objects as go
trace1 = go.Scatter(
    x = date_train,
    y = close_data,
    mode = 'lines',
    name = 'Data'
)

# %%
trace2 = go.Scatter(
    x = date_test,
    y = prediction,
    mode = 'lines',
    name = 'Prediction'
)
trace3 = go.Scatter(
    x = date_test,
    y = close_testdata,
    mode='lines',
    name = 'Ground Truth'
)
layout = go.Layout(
    title = "Google Stock",
    xaxis = {'title' : "Date"},
    yaxis = {'title' : "Close"}
)
fig = go.Figure(data=[trace1, trace2, trace3], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8a1f677d-19e5-48ab-8c0e-ed689b888bf3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8a1f677d-19e5-48ab-8c0e-ed689b888bf3")) {
#                     Plotly.newPlot(
#                         '8a1f677d-19e5-48ab-8c0e-ed689b888bf3',
# ...
